# %%
from mlx_vlm import convert

# Convert your Hugging Face VLM to MLX format
convert(
    "./api/models/SceneModel",
    mlx_path="./models/SceneModel",
    quantize=True,  # Reduce model size
    q_bits=4        # 4-bit quantization
)
# Out:
# ERROR:root:Model type vision-encoder-decoder not supported.
# [INFO] Loading
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Technology/mlstudios/repos/SecondSight-API/venv/lib/python3.11/site-packages/mlx_vlm/utils.py:106, in get_model_and_args(config)
#     103 if not model_path.exists():
#     104     model_path = Path(
#     105         snapshot_download(
# --> 106             repo_id=path_or_hf_repo,
#     107             revision=revision,
#     108             allow_patterns=[
#     109                 "*.json",
#     110                 "*.safetensors",
#     111                 "*.py",
#     112                 "*.model",
#     113                 "*.tiktoken",
#     114                 "*.txt",
#     115                 "*.jinja",
#     116             ],
#     117             force_download=force_download,
#     118         )
#     119     )
# ...
