# %%
from ultralytics import YOLO

# Load your YOLO model (replace with your .pt file)
model = YOLO("models/best.pt")


# Export to Core ML format
model.export(format="coreml", 
             nms=True,
             project="models/",
             name="DetectionYOLO11n")  # This creates 'your_model.mlpackage'
# Out:
# Ultralytics 8.3.115 🚀 Python-3.9.6 torch-2.5.1 CPU (Apple M4 Max)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'models/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (5.2 MB)
#
# CoreML: starting export with coremltools 8.3.0...
# Tuple detected at graph output. This will be flattened in the converted model.
# Converting PyTorch Frontend ==> MIL Ops: 100%|█████████▉| 708/710 [00:00<00:00, 7283.12 ops/s]
# Running MIL frontend_pytorch pipeline: 100%|██████████| 5/5 [00:00<00:00, 163.59 passes/s]
# Running MIL default pipeline: 100%|██████████| 89/89 [00:00<00:00, 101.69 passes/s]
# Running MIL backend_mlprogram pipeline: 100%|██████████| 12/12 [00:00<00:00, 170.56 passes/s]
# CoreML Pipeline: starting pipeline with coremltools 8.3.0...
# CoreML Pipeline: pipeline success
# CoreML: export success ✅ 14.9s, saved as 'models/best.mlpackage' (5.1 MB)
#
# Export complete (15.0s)
# Results saved to /Users/jasper/Anna/Uni/UTS/MAI/Subjects/AIS/project/SecondSight-API/models
# Predict:         yolo predict task=detect model=models/best.mlpackage imgsz=640
# Validate:        yolo val task=detect model=models/best.mlpackage imgsz=640 data=/var/folders/ry/_htx3qqn3wz0y1xcr5lcfc6c0000gn/T/tmpqdkpgch2/Detection_Dev/data.yaml
# Visualize:       https://netron.app
# 'models/best.mlpackage'
